# %% [markdown]
# <a href="https://colab.research.google.com/github/roopa653-fairy/Leetcode-solutions/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
array=[1,2,3,4]
print(type(array))
array=np.array(array)
array=array*2
print(type(array))
print(array)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# [2 4 6 8]
